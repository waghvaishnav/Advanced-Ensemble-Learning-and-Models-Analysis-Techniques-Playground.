# %% [markdown]
# <a href="https://colab.research.google.com/github/waghvaishnav/Advanced-Ensemble-Learning-and-Models-Analysis-Techniques-Playground./blob/main/Bagging_BaggingClassifier_in_Ensemble_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# Load data
data = load_iris()
x = data.data
y = data.target

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Base model
dt = SVC(kernel="rbf")

# Bagging Classifier
bag_clf = BaggingClassifier(estimator=dt, n_estimators=50, random_state=42)
bag_clf.fit(x_train, y_train)

# Predict
y_pred = bag_clf.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred)*100)
print("classification_report is the :", classification_report(y_test, y_pred))
# Out:
# Accuracy: 100.0
# classification_report is the :               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# Load data
data = load_iris()
x = data.data
y = data.target

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Base model
dt = DecisionTreeClassifier()

# Bagging Classifier
bag_clf = BaggingClassifier(estimator=dt, n_estimators=50, random_state=42)
bag_clf.fit(x_train, y_train)

# Predict
y_pred = bag_clf.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred)*100)
print("classification_report is the :", classification_report(y_test, y_pred))
# Out:
# Accuracy: 100.0
# classification_report is the :               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
