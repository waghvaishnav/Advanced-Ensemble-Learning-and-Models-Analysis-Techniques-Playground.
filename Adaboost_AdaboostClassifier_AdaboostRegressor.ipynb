# %% [markdown]
# <a href="https://colab.research.google.com/github/waghvaishnav/Advanced-Ensemble-Learning-and-Models-Analysis-Techniques-Playground./blob/main/Adaboost_AdaboostClassifier_AdaboostRegressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AdaboostClassifier :

# %%
from sklearn.datasets import load_iris
from sklearn.metrics import classification_report
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
import pandas as pd

data = load_iris()
x = data.data
y = data.target

x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.3)

ada_model = AdaBoostClassifier(n_estimators=21,learning_rate=1.0)                 # without the estimator or base model adaboost just a decision tree algo like max_depth = 1.

ada_model.fit(x_train,y_train)

prediction = ada_model.predict(x_test)

result = classification_report(y_test,prediction)
print(result)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
from sklearn.datasets import load_iris
from sklearn.metrics import classification_report
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import pandas as pd

data = load_iris()
x = data.data
y = data.target

x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.3)

base_model = DecisionTreeClassifier(max_depth=1)
ada_model = AdaBoostClassifier(estimator=base_model,n_estimators=21,learning_rate=1.0)

ada_model.fit(x_train,y_train)

prediction = ada_model.predict(x_test)

result = classification_report(y_test,prediction)
print(result)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
from sklearn.datasets import load_iris
from sklearn.metrics import classification_report
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import pandas as pd

data = load_iris()
x = data.data
y = data.target

x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.3)

base_model = LogisticRegression()
ada_model = AdaBoostClassifier(estimator=base_model,n_estimators=21,learning_rate=1.0)

ada_model.fit(x_train,y_train)

prediction = ada_model.predict(x_test)

result = classification_report(y_test,prediction)
print(result)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      0.38      0.56        13
#            2       0.62      1.00      0.76        13
#
#     accuracy                           0.82        45
#    macro avg       0.87      0.79      0.77        45
# weighted avg       0.89      0.82      0.80        45

# %% [markdown]
# #AdaboostRegressor :

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Load dataset
data = fetch_california_housing()
X, y = data.data, data.target

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# --- Base model
base = DecisionTreeRegressor(max_depth=3)

# --- AdaBoost Regressor
model = AdaBoostRegressor(
    estimator=base,
    n_estimators=50,
    learning_rate=0.5,
    loss='linear',
    random_state=42
)

# Train model
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluate
print("R² Score:", r2_score(y_test, y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
# Out:
# R² Score: 0.49703472142708516
# Mean Squared Error: 0.6601621009647234
